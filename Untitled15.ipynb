# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
tips= pd.read_csv('/content/AI_index_db.csv')

# %%
tips.head()
# Out:
#                     Country  Talent  Infrastructure  Operating Environment  \
# 0  United States of America  100.00           94.02                  64.56
# 1                     China   16.51          100.00                  91.57
# 2            United Kingdom   39.65           71.43                  74.65
# 3                    Canada   31.28           77.05                  93.94
# 4                    Israel   35.76           67.58                  82.44
#
#    Research  Development  Government Strategy  Commercial  Total score  \
# 0    100.00       100.00                77.39      100.00       100.00
# 1     71.42        79.97                94.87       44.02        62.92
# 2     36.50        25.03                82.82       18.91        40.93
# 3     30.67        25.78               100.00       14.88        40.19
# 4     32.63        27.96                43.91       27.33        39.89
#
#          Region                Cluster  Income group   Political regime
# ...

# %%
sns.distplot
# Out:
# <function seaborn.distributions.distplot(a=None, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None, x=None)>

# %%
sns.distplot(tips['Research'], kde = False)
# Out:
# /tmp/ipython-input-16-768688841.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['Research'], kde = False)
# <Axes: xlabel='Research'>

# %%
sns.distplot(tips['Commercial'], hist = False, vertical= True, color = 'red')
# Out:
# /tmp/ipython-input-14-2295145436.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['Commercial'], hist = False, vertical= True, color = 'red')
# <Axes: xlabel='Density', ylabel='Commercial'>

# %%
sns.jointplot(x = 'Operating Environment', y = 'Research', data = tips)

# %%
sns.jointplot(x = 'Operating Environment', y = 'Research', data = tips, kind = 'kde')

# %%
sns.jointplot(x = 'Talent', y = 'Government Strategy', data = tips, kind = 'kde', color = 'red')

# %%
sns.jointplot(x = 'Operating Environment', y = 'Research', data = tips, kind = 'hex')

# %%
sns.pairplot(tips)

# %%
tips.head()
# Out:
#                     Country  Talent  Infrastructure  Operating Environment  \
# 0  United States of America  100.00           94.02                  64.56
# 1                     China   16.51          100.00                  91.57
# 2            United Kingdom   39.65           71.43                  74.65
# 3                    Canada   31.28           77.05                  93.94
# 4                    Israel   35.76           67.58                  82.44
#
#    Research  Development  Government Strategy  Commercial  Total score  \
# 0    100.00       100.00                77.39      100.00       100.00
# 1     71.42        79.97                94.87       44.02        62.92
# 2     36.50        25.03                82.82       18.91        40.93
# 3     30.67        25.78               100.00       14.88        40.19
# 4     32.63        27.96                43.91       27.33        39.89
#
#          Region                Cluster  Income group   Political regime
# ...

# %%
sns.pairplot(tips, hue = 'Commercial')

# %%
sns.pairplot(tips, hue = '', palette = 'Total score')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     234                 # Perhaps a named matplotlib colormap?
# --> 235                 palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236             except (ValueError, KeyError):  # Error class changed in mpl36
#
# /usr/local/lib/python3.11/dist-packages/seaborn/palettes.py in mpl_palette(name, n_colors, as_cmap)
#     405     else:
# --> 406         cmap = get_colormap(name)
#     407
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_compat.py in get_colormap(name)
#      61     try:
# ---> 62         return mpl.colormaps[name]
#      63     except AttributeError:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/cm.py in __getitem__(self, item)
#      97         except KeyError:
# ...
